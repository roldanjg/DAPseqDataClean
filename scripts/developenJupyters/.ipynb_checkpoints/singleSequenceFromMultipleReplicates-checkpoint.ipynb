# %%
# TODO extract the common sequence of the regulation in each fragment.
#https://stackoverflow.com/questions/10016802/grouping-a-list-of-integers-with-nearest-values
import glob
import os
import time
from statistics import mean
basePathDataFolder = '/home/joaquin/projects/methylation/data'
dataFolder = 'allDataNarrowPeaksmin2repNineCoincidence'
dataFolderDestination = 'allDataNarrowPeaksmin2repNineCoincidenceSingleSequence'
separationValue = 20
folderPath = os.path.join(
                basePathDataFolder,dataFolder
            )
listOfFiles = glob.glob(folderPath+'/*')



def saveFile(dictOfCommonNPEvents, destinationFilePath):
    
    with open(destinationFilePath, 'a') as destFile:
        for chrm in dictOfCommonNPEvents:
            for coordinates in dictOfCommonNPEvents[chrm]:
                destFile.write('chr{}\t{}\t{}\n'.format(chrm,coordinates[0],coordinates[1]))
                
for fileName in listOfFiles:
    dictOfCommonNPEvents = {}
    
    destinationFilePath = os.path.join(
                basePathDataFolder,dataFolderDestination, fileName.split('/')[-1]
            )
    #Just keep the 3erd col that contains the center coordinate and the chr, split : to separate
    #chr:coordinate, and generate a list to work with
    print(fileName)
    with open(fileName, 'r') as NPEvents:
        for line in NPEvents:
            chrAndCoor = list(map(lambda x: int(x), line.strip().split('\t')[3].split(':')))
            dictOfCommonNPEvents.setdefault(chrAndCoor[0], [])
            dictOfCommonNPEvents[chrAndCoor[0]].append(chrAndCoor[1])
    for chrm in dictOfCommonNPEvents:

        m = [[dictOfCommonNPEvents[chrm][0]]]
        
        for x in dictOfCommonNPEvents[chrm][1:]:

                if x - m[-1][-1] < separationValue:
                    m[-1].append(x)
                else:
                    meanValPeak = int(mean(m[-1]))
                    m.pop()
                    m.append([meanValPeak-100,meanValPeak+101])
                    m.append([x])

        meanValPeak = int(mean(m[-1]))
        m.pop()
        m.append([meanValPeak-100,meanValPeak+101])
        dictOfCommonNPEvents[chrm] = m
    
    saveFile(dictOfCommonNPEvents, destinationFilePath)
    print
# Out:
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC324ACC_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH76ACC_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH724JA_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC31JA_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH71JA_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH724JA_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC36Mock_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH724ACC_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC36ACC_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH724Mock_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC31Mock_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC324JA_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH71Mock_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH71ACC_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC36ACC_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC324JA_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH71ACC_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC36JA_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC324ACC_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH76ACC_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH71JA_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC31ACC_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH76Mock_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC31ACC_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH724ACC_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC324Mock_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH76JA_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC36JA_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH724Mock_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC31JA_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC324Mock_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH76Mock_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC36Mock_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH71Mock_direct_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYCH76JA_amplified_replicates_common_Peaks_min_2_reps.narrowPeak
# /home/joaquin/projects/methylation/data/allDataNarrowPeaksmin2repNineCoincidence/MYC31Mock_direct_replicates_common_Peaks_min_2_reps.narrowPeak

# %%
import glob
import os
import time
from statistics import mean
basePathDataFolder = '/home/joaquin/projects/methylation/data'
dataFolder = 'allDataNarrowPeaksmin2repSixCoincidenceSingleSequence'
folderPath = os.path.join(
                basePathDataFolder,dataFolder
            )
listOfFiles = glob.glob(folderPath+'/*')


summaryTableName = 'summaryTableIndividualPeaks.tsv'
summaryTableNamePath = os.path.join(
                basePathDataFolder,dataFolder, 'summaryTableIndividualPeaks.tsv'
            )

with open(summaryTableNamePath, 'a') as summary:
    for fileName in listOfFiles:

        total = sum(1 for line in open(fileName))

        summary.write(
            '{}\t{}\t{}\n'.format(
                fileName.split('/')[-1].split('_')[0],
                      fileName.split('/')[-1].split('_')[1],total)
        )

    #num_lines = sum(1 for line in open(narrowpeakMeanval))
